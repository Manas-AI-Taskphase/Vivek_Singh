# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dinos.csv")

print(np.unique(df.iloc[:,0]))
# Out:
# ['Brachiosaurus' 'Iguanadon' 'Plateosaurus' 'Pterodactyl' 'Raptor'
#  'Stegosaurus' 'Vulcanodon']

# %%
df_scaled = df.drop("Weight", axis=1)
df_scaled["Gender"] = (df_scaled["Gender"]=="M").astype("int16")
df_scaled = df_scaled.assign(Volume=df_scaled["Length"]*df_scaled["Height"]*df_scaled["Width"])

df_scaled = df_scaled.drop("Species", axis=1)

m,n=df_scaled.shape

# An attempt to use the Species Feature
"""
for i in range(m):
    if df_scaled["Species"][i] == "Iguanadon":
        df_scaled["Species"][i] = 1.0
    elif df_scaled["Species"][i] == "Pterodactyl":
        df_scaled["Species"][i] = 2.0
    elif df_scaled["Species"][i] == "Brachiosaurus":
        df_scaled["Species"][i] = 3.0
    elif df_scaled["Species"][i] == "Stegosaurus":
        df_scaled["Species"][i] = 4.0
    elif df_scaled["Species"][i] == "Plateosaurus":
        df_scaled["Species"][i] = 5.0
    elif df_scaled["Species"][i] == "Vulcanodon":
        df_scaled["Species"][i] = 6.0
"""


df_scaled.head()
# Out:
#    Length   Age  TailLength   Height  Width  Gender  Completeness       Volume
# 0    59.0  63.4        68.0  10.8120  7.480       1         0.545  4771.551840
# 1    22.0  24.0        25.5   6.3750  3.825       1         0.531   536.456250
# 2    37.1  40.0        42.5  11.1350  6.630       0         0.661  2738.909355
# 3    23.2  25.4        30.0  11.5200  4.020       0         0.793  1074.401280
# 4    36.5  39.0        41.4  11.1366  6.003       1         0.931  2440.134858

# %%
for i in range(n):
    print(type(df_scaled.iloc[:,i][0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int16'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %% [markdown]
# # Scaling

# %%
# Min-Max Scaling (Normalization)
"""
for i in range(n):
    series = df_scaled.iloc[:, i]
    min_value = series.min()
    max_value = series.max()
    df_scaled.iloc[:, i] = (series - min_value) / (max_value - min_value)
"""

#standardization Scaling 

for i in range(n):    
    x= df_scaled.iloc[:, i]
    mean_value = x.mean()
    std_deviation = abs(x.std())
    stanadardized_x = (x - mean_value) / std_deviation
    df_scaled.iloc[:, i]= stanadardized_x


df_scaled.head()
# Out:
#      Length       Age  TailLength    Height     Width    Gender  Completeness  \
# 0  3.276449  3.264577    3.167285  0.429519  1.816649  0.895402      0.014552
# 1 -0.424868 -0.412056   -0.493275 -0.605662 -0.351456  0.895402     -0.037028
# 2  1.085669  1.080993    0.970949  0.504877  1.312439 -1.109793      0.441923
# 3 -0.304825 -0.281414   -0.105686  0.594700 -0.235784 -1.109793      0.928243
# 4  1.025648  0.987678    0.876205  0.505250  0.940509  0.895402      1.436668
#
#      Volume
# 0  2.642208
# 1 -0.698052
# 2  1.039043
# 3 -0.273770
# 4  0.803397

# %%
cols = ["Length", "Age", "TailLength", "Height", "Width", "Gender", "Completeness", "Volume"]

for label in cols:
    plt.scatter(df_scaled[label], Y)
    plt.title(label)
    plt.show()

# %% [markdown]
# Since *Completenes* does not to have any relation to weigth we will dorp it from the dataframe

# %%
df_scaled = df_scaled.drop("Completeness", axis=1)
#df_scaled = df_scaled.drop("Volume", axis=1)

# %% [markdown]
# # Test and Train split

# %%
train, test = np.split(df_scaled, [int(0.7*len(df_scaled))])

Y, Y_test = np.split(df["Weight"], [int(0.7*len(df["Weight"]))])

# %%
Y = df["Weight"]
X = train.to_numpy()
#cols = ["Length", "Age", "TailLength", "Height", "Width", "Gender", "Volume"]
m,n = train.shape

# %% [markdown]
# As most of the data seems to following an exponential graph an exponential curve would be better fitting to to the model.

# %%
w = np.zeros(n) #parameter vector
b=0

alpha = 0.01 #learniing rate
#exp 0.0001
lamb = 1000# regularization factor
#exp 200000

epochs = 1000 #number of iterations
#exp 1000

Cost=np.zeros(epochs)
iter = np.linspace(0, epochs-1, epochs)

for i in range(epochs):
    Y_pred = pd.Series(np.zeros(m))#a pandas series 
    
    #linear curve (line)
    Y_pred = np.dot(X, w) + b * pd.Series(np.ones(m)) 

    #exponential curve
    #Y_pred = np.exp(X@w + b * pd.Series(np.ones(m))) 
    
    D_w = (1/m)*np.sum(Y_pred- Y)*X + (lamb/(2*m))*w
    D_b = (1/m)*np.sum(Y_pred- Y)

    cost = (1/(2*m))*np.sum(pow(Y_pred-Y, 2)) + (lamb/(2*m))*np.sum(w**2)
    #exp cost = to be figured
    Cost[i]= cost
    
    w = w - alpha * D_w[1]
    b = b - alpha * D_b

print(w, b)
# Out:
# [-0.0026506  -0.00257067 -0.00307737 -0.00377851 -0.00219261  0.0055861
#  -0.0043549 ] 390.20427746742075

# %%
plt.plot(iter, Cost)
plt.show()

# %%
print(Cost.min())
# Out:
# 67880.11660789575

# %%
print(cost)
# Out:
# 67880.11660789575

# %%
X_test = test.to_numpy()
cols = ["Length", "Age", "TailLength", "Height", "Width", "Gender", "Volume"]
m_test, n_test = test.shape
test.shape
# Out:
# (48, 7)

# %%
Y_test_pred = X_test @ w + b
cost_test = (1/(2*m_test))*np.sum(pow(Y_test_pred-Y_test, 2)) 
print(cost_test)
# Out:
# 54066.40765142683

# %%
error_test = abs(Y_test_pred - Y_test)
error_test_p = np.sum(error_test*100/Y_test)
print(error_test_p)
# Out:
# 26941.57667367168
